# %% [markdown]
# **INDRODUCTION**
#
# Exploratory Data Analysis(EDA) is a process of examining the data, extracting insights of the data.Originally developed by American mathematician John Tukey in the 1970s, EDA techniques continue to be a widely used method in the data discovery process today.In statistics, EDA is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methods.

# %% [markdown]
# # **Load** **Data**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
print(df.to_string())
# Out:
#                                                    country country_code                 region  year  life_expect  life_exp60  adult_mortality  infant_mort  age1-4mort   alcohol   bmi  age5-19thinness  age5-19obesity  hepatitis  measles  polio  diphtheria  basic_water  doctors  hospitals  gni_capita    gghe-d   che_gdp      une_pop  une_infant  une_life  une_hiv   une_gni  une_poverty  une_edu_spend  une_literacy  une_school
# 0                                                   Angola          AGO                 Africa  2000     47.33730    14.73400        383.55830     0.137985    0.025695   1.47439  21.7             11.0             0.5        NaN     32.0   21.0        31.0     41.14431      NaN        NaN      2190.0   1.11099   1.90860    16395.473       122.2  46.52200      1.0    2530.0         32.3        2.60753           NaN         NaN
# ...

# %% [markdown]
# # **Load** **Head**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.head()
# Out:
#   country country_code  region  year  life_expect  life_exp60  \
# 0  Angola          AGO  Africa  2000     47.33730    14.73400
# 1  Angola          AGO  Africa  2001     48.19789    14.95963
# 2  Angola          AGO  Africa  2002     49.42569    15.20010
# 3  Angola          AGO  Africa  2003     50.50266    15.39144
# 4  Angola          AGO  Africa  2004     51.52863    15.56860
#
#    adult_mortality  infant_mort  age1-4mort  alcohol  ...  che_gdp    une_pop  \
# 0         383.5583     0.137985    0.025695  1.47439  ...  1.90860  16395.473
# 1         372.3876     0.133675    0.024500  1.94025  ...  4.48352  16945.753
# 2         354.5147     0.128320    0.023260  2.07512  ...  3.32946  17519.417
# 3         343.2169     0.122040    0.021925  2.20275  ...  3.54797  18121.479
# 4         333.8711     0.115700    0.020545  2.41274  ...  3.96720  18758.145
#
#    une_infant  une_life  une_hiv  une_gni  une_poverty  une_edu_spend  \
# ...

# %% [markdown]
# # **Load** **Colums**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.columns
# Out:
# Index(['country', 'country_code', 'region', 'year', 'life_expect',
#        'life_exp60', 'adult_mortality', 'infant_mort', 'age1-4mort', 'alcohol',
#        'bmi', 'age5-19thinness', 'age5-19obesity', 'hepatitis', 'measles',
#        'polio', 'diphtheria', 'basic_water', 'doctors', 'hospitals',
#        'gni_capita', 'gghe-d', 'che_gdp', 'une_pop', 'une_infant', 'une_life',
#        'une_hiv', 'une_gni', 'une_poverty', 'une_edu_spend', 'une_literacy',
#        'une_school'],
#       dtype='object')

# %% [markdown]
# ##**Load Data Types**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.dtypes
# Out:
# country             object
# country_code        object
# region              object
# year                 int64
# life_expect        float64
# life_exp60         float64
# adult_mortality    float64
# infant_mort        float64
# age1-4mort         float64
# alcohol            float64
# bmi                float64
# age5-19thinness    float64
# age5-19obesity     float64
# hepatitis          float64
# measles            float64
# polio              float64
# diphtheria         float64
# basic_water        float64
# doctors            float64
# hospitals          float64
# gni_capita         float64
# gghe-d             float64
# che_gdp            float64
# une_pop            float64
# une_infant         float64
# une_life           float64
# une_hiv            float64
# une_gni            float64
# une_poverty        float64
# une_edu_spend      float64
# une_literacy       float64
# une_school         float64
# dtype: object

# %% [markdown]
# **Info**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          3111 non-null   object
#  1   country_code     3111 non-null   object
#  2   region           3111 non-null   object
#  3   year             3111 non-null   int64
#  4   life_expect      3111 non-null   float64
#  5   life_exp60       3111 non-null   float64
#  6   adult_mortality  3111 non-null   float64
#  7   infant_mort      3111 non-null   float64
#  8   age1-4mort       3111 non-null   float64
#  9   alcohol          3061 non-null   float64
#  10  bmi              3077 non-null   float64
#  11  age5-19thinness  3077 non-null   float64
#  12  age5-19obesity   3077 non-null   float64
#  13  hepatitis        2542 non-null   float64
#  14  measles          3092 non-null   float64
#  15  polio            3092 non-null   float64
# ...

# %% [markdown]
# # **Load Describe**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.describe()
# Out:
#               year  life_expect   life_exp60  adult_mortality  infant_mort  \
# count  3111.000000  3111.000000  3111.000000      3111.000000  3111.000000
# mean   2008.000000    69.146384    18.912060       193.527786     0.032496
# std       4.899767     9.129761     2.885412       114.007447     0.030361
# min    2000.000000    36.227360    10.728000        49.201850     0.001470
# 25%    2004.000000    63.200095    16.619485       108.269750     0.008255
# 50%    2008.000000    71.597200    18.508260       164.822200     0.019995
# 75%    2012.000000    75.537030    21.099175       250.832300     0.051720
# max    2016.000000    84.166160    26.394020       696.874200     0.164515
#
#         age1-4mort      alcohol          bmi  age5-19thinness  age5-19obesity  \
# count  3111.000000  3061.000000  3077.000000      3077.000000     3077.000000
# mean      0.003489     4.834781    25.052714         5.312447        5.972278
# ...

# %% [markdown]
# #**Group by**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.groupby
# Out:
# <bound method DataFrame.groupby of                                country country_code           region  year  \
# 0                               Angola          AGO           Africa  2000
# 1                               Angola          AGO           Africa  2001
# 2                               Angola          AGO           Africa  2002
# 3                               Angola          AGO           Africa  2003
# 4                               Angola          AGO           Africa  2004
# ...                                ...          ...              ...   ...
# 3106  Lao People's Democratic Republic          LAO  Western Pacific  2012
# 3107  Lao People's Democratic Republic          LAO  Western Pacific  2013
# 3108  Lao People's Democratic Republic          LAO  Western Pacific  2014
# 3109  Lao People's Democratic Republic          LAO  Western Pacific  2015
# 3110  Lao People's Democratic Republic          LAO  Western Pacific  2016
#
# ...

# %% [markdown]
# **Filter THE DATA**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df[df['age5-19obesity']==1].head()
# Out:
#          country country_code  region  year  life_expect  life_exp60  \
# 7         Angola          AGO  Africa  2007     54.97549    16.09804
# 27       Burundi          BDI  Africa  2010     57.55196    16.29294
# 36         Benin          BEN  Africa  2002     56.10347    16.42120
# 37         Benin          BEN  Africa  2003     56.37336    16.42891
# 67  Burkina Faso          BFA  Africa  2016     60.32101    15.48575
#
#     adult_mortality  infant_mort  age1-4mort  alcohol  ...   che_gdp  \
# 7          302.8322     0.096850    0.015920  4.67969  ...   2.97439
# 27         322.7220     0.063755    0.009140  4.48499  ...  11.27638
# 36         283.6871     0.091855    0.014550  1.34153  ...   4.15323
# 37         284.5348     0.089235    0.014015  1.46304  ...   4.14783
# 67         254.6027     0.055795    0.008635  7.10585  ...   7.01312
#
#       une_pop  une_infant  une_life  une_hiv  une_gni  une_poverty  \
# ...

# %% [markdown]
# **A QUICK BOXPLOT OF DATASET**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df[['life_expect']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# **CORRELATION**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.corr()
# Out:
# <ipython-input-23-40eb45752781>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      year  life_expect  life_exp60  adult_mortality  \
# year             1.000000     0.190961    0.192872        -0.170946
# life_expect      0.190961     1.000000    0.886159        -0.946419
# life_exp60       0.192872     0.886159    1.000000        -0.775321
# adult_mortality -0.170946    -0.946419   -0.775321         1.000000
# infant_mort     -0.195293    -0.930113   -0.769839         0.813210
# age1-4mort      -0.191723    -0.864414   -0.661082         0.756230
# alcohol          0.006428     0.399797    0.465785        -0.246530
# bmi              0.170244     0.597996    0.458839        -0.517095
# age5-19thinness -0.081810    -0.565396   -0.556536         0.455205
# ...

# %% [markdown]
# **CORRELATION** **PLOT**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_excel('/content/who_life_exp.xlsx')
sns.heatmap(df.corr())
# Out:
# <ipython-input-24-360ec1068037>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# **MEAN**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.mean()
# Out:
# <ipython-input-26-6e9735945265>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# year                2008.000000
# life_expect           69.146384
# life_exp60            18.912060
# adult_mortality      193.527786
# infant_mort            0.032496
# age1-4mort             0.003489
# alcohol                4.834781
# bmi                   25.052714
# age5-19thinness        5.312447
# age5-19obesity         5.972278
# hepatitis             85.436271
# measles               85.540427
# polio                 86.608991
# diphtheria            86.420116
# basic_water           83.332011
# doctors               19.866038
# hospitals              2.044878
# gni_capita         13397.146974
# gghe-d                 3.122935
# ...

# %% [markdown]
# **MEADIAN**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.median()
# Out:
# <ipython-input-27-76df6f92f963>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# year               2008.000000
# life_expect          71.597200
# life_exp60           18.508260
# adult_mortality     164.822200
# infant_mort           0.019995
# age1-4mort            0.000895
# alcohol               3.993560
# bmi                  25.500000
# age5-19thinness       3.800000
# age5-19obesity        5.200000
# hepatitis            92.000000
# measles              92.000000
# polio                93.000000
# diphtheria           93.000000
# basic_water          91.994080
# doctors              20.523500
# hospitals             1.072725
# gni_capita         7460.000000
# gghe-d                2.601300
# che_gdp               5.758030
# ...

# %% [markdown]
# **MODE**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.mode()
# Out:
#                  country country_code  region    year  life_expect  \
# 0            Afghanistan          AFG  Europe  2000.0     67.03989
# 1                Albania          AGO     NaN  2001.0     71.80817
# 2                Algeria          ALB     NaN  2002.0          NaN
# 3                 Angola          ARE     NaN  2003.0          NaN
# 4    Antigua and Barbuda          ARG     NaN  2004.0          NaN
# ..                   ...          ...     ...     ...          ...
# 800                  NaN          NaN     NaN     NaN          NaN
# 801                  NaN          NaN     NaN     NaN          NaN
# 802                  NaN          NaN     NaN     NaN          NaN
# 803                  NaN          NaN     NaN     NaN          NaN
# 804                  NaN          NaN     NaN     NaN          NaN
#
#      life_exp60  adult_mortality  infant_mort  age1-4mort  alcohol  ...  \
# 0      15.18697         265.0517      0.00355    0.000175      0.0  ...
# ...

# %% [markdown]
# **STANDERD** **DEVIATION**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.std()
# Out:
# <ipython-input-30-e98ff7f1bcb7>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# year                    4.899767
# life_expect             9.129761
# life_exp60              2.885412
# adult_mortality       114.007447
# infant_mort             0.030361
# age1-4mort              0.005146
# alcohol                 3.998741
# bmi                     2.193445
# age5-19thinness         4.652408
# age5-19obesity          4.530812
# hepatitis              17.099786
# measles                15.282246
# polio                  14.943226
# diphtheria             15.332160
# basic_water            19.255119
# doctors                14.071207
# hospitals               5.059339
# gni_capita          16258.593973
# gghe-d                  2.091720
# ...

# %% [markdown]
# **SUM OF NULL VALUES OF EACH COLUMS**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.isnull().sum()
# Out:
# country               0
# country_code          0
# region                0
# year                  0
# life_expect           0
# life_exp60            0
# adult_mortality       0
# infant_mort           0
# age1-4mort            0
# alcohol              50
# bmi                  34
# age5-19thinness      34
# age5-19obesity       34
# hepatitis           569
# measles              19
# polio                19
# diphtheria           19
# basic_water          32
# doctors            1331
# hospitals          2981
# gni_capita          682
# gghe-d              100
# che_gdp             117
# une_pop              37
# une_infant            0
# une_life              0
# une_hiv             741
# une_gni             117
# une_poverty        2198
# une_edu_spend      1286
# une_literacy       2540
# une_school         2306
# dtype: int64

# %% [markdown]
# **Sum of Duplicats of data**

# %%
import pandas as pd
df = pd.read_excel('/content/who_life_exp.xlsx')
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Reseting index of data

# %% [markdown]
# **CHECK** **FOR DUPLICATION**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df.nunique()
# Out:
# country             183
# country_code        183
# region                6
# year                 17
# life_expect        3109
# life_exp60         3107
# adult_mortality    3110
# infant_mort        2728
# age1-4mort         1324
# alcohol            2980
# bmi                 122
# age5-19thinness     227
# age5-19obesity      213
# hepatitis            92
# measles              78
# polio                77
# diphtheria           79
# basic_water        2699
# doctors            1737
# hospitals           128
# gni_capita         1559
# gghe-d             3004
# che_gdp            2988
# une_pop            3073
# une_infant          867
# une_life           2944
# une_hiv             187
# une_gni            1870
# une_poverty         291
# une_edu_spend      1824
# une_literacy        565
# une_school          805
# dtype: int64

# %% [markdown]
# **CALCULATE THE PERCENTAGE OF MISSING VALUES IN EACH COLUMN**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
(df.isnull().sum()/(len(df)))*100
# Out:
# country             0.000000
# country_code        0.000000
# region              0.000000
# year                0.000000
# life_expect         0.000000
# life_exp60          0.000000
# adult_mortality     0.000000
# infant_mort         0.000000
# age1-4mort          0.000000
# alcohol             1.607200
# bmi                 1.092896
# age5-19thinness     1.092896
# age5-19obesity      1.092896
# hepatitis          18.289939
# measles             0.610736
# polio               0.610736
# diphtheria          0.610736
# basic_water         1.028608
# doctors            42.783671
# hospitals          95.821279
# gni_capita         21.922212
# gghe-d              3.214401
# che_gdp             3.760849
# une_pop             1.189328
# une_infant          0.000000
# une_life            0.000000
# une_hiv            23.818708
# une_gni             3.760849
# une_poverty        70.652523
# une_edu_spend      41.337191
# une_literacy       81.645773
# une_school         74.124076
# ...

# %% [markdown]
# **COUNT** **UNICOLUMQE VALUES OF infant_mort ** ***

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df['infant_mort'].value_counts()
# Out:
# 0.003550    5
# 0.003450    4
# 0.004580    4
# 0.003315    4
# 0.003185    4
#            ..
# 0.025125    1
# 0.024900    1
# 0.024320    1
# 0.023655    1
# 0.051895    1
# Name: infant_mort, Length: 2728, dtype: int64

# %% [markdown]
# **SUM**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df.sum()
# Out:
# country            AngolaAngolaAngolaAngolaAngolaAngolaAngolaAngo...
# country_code       AGOAGOAGOAGOAGOAGOAGOAGOAGOAGOAGOAGOAGOAGOAGOA...
# region             AfricaAfricaAfricaAfricaAfricaAfricaAfricaAfri...
# year                                                         6246888
# life_expect                                             215114.39995
# life_exp60                                               58835.41868
# adult_mortality                                         602064.94169
# infant_mort                                                101.09464
# age1-4mort                                                 10.855575
# alcohol                                                  14799.26533
# bmi                                                          77087.2
# age5-19thinness                                              16346.4
# age5-19obesity                                               18376.7
# hepatitis                                                   217179.0
# ...

# %% [markdown]
# **COUNT**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df.count()
# Out:
# country            3111
# country_code       3111
# region             3111
# year               3111
# life_expect        3111
# life_exp60         3111
# adult_mortality    3111
# infant_mort        3111
# age1-4mort         3111
# alcohol            3061
# bmi                3077
# age5-19thinness    3077
# age5-19obesity     3077
# hepatitis          2542
# measles            3092
# polio              3092
# diphtheria         3092
# basic_water        3079
# doctors            1780
# hospitals           130
# gni_capita         2429
# gghe-d             3011
# che_gdp            2994
# une_pop            3074
# une_infant         3111
# une_life           3111
# une_hiv            2370
# une_gni            2994
# une_poverty         913
# une_edu_spend      1825
# une_literacy        571
# une_school          805
# dtype: int64

# %% [markdown]
# **CALCULATE THE PERCENTAGE OF MISSING VALUES IN EACH COLUMN**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df.loc[(df['country']=='Angola') & (df['year']< 2000) & (df['life_expect']==383.5583)]
# Out:
# Empty DataFrame
# Columns: [country, country_code, region, year, life_expect, life_exp60, adult_mortality, infant_mort, age1-4mort, alcohol, bmi, age5-19thinness, age5-19obesity, hepatitis, measles, polio, diphtheria, basic_water, doctors, hospitals, gni_capita, gghe-d, che_gdp, une_pop, une_infant, une_life, une_hiv, une_gni, une_poverty, une_edu_spend, une_literacy, une_school]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# **Filtering Data Based on certain columns**

# %%
import pandas as pd
df=pd.read_excel('/content/who_life_exp.xlsx')
df[df.life_expect>40|(df.life_exp60==47.3373)]
# Out:
#                                country country_code           region  year  \
# 0                               Angola          AGO           Africa  2000
# 1                               Angola          AGO           Africa  2001
# 2                               Angola          AGO           Africa  2002
# 3                               Angola          AGO           Africa  2003
# 4                               Angola          AGO           Africa  2004
# ...                                ...          ...              ...   ...
# 3106  Lao People's Democratic Republic          LAO  Western Pacific  2012
# 3107  Lao People's Democratic Republic          LAO  Western Pacific  2013
# 3108  Lao People's Democratic Republic          LAO  Western Pacific  2014
# 3109  Lao People's Democratic Republic          LAO  Western Pacific  2015
# 3110  Lao People's Democratic Republic          LAO  Western Pacific  2016
#
# ...

# %% [markdown]
# ##**Distplot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/who_life_exp.xlsx')
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)
sns.distplot(df['adult_mortality'])
plt.show()

# %% [markdown]
# ## **Histplot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/who_life_exp.xlsx')
sns.histplot(df['adult_mortality'],palette='hls')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
df.groupby(['Country']).sum().plot( kind='pie',y='Year',autopct='%1.0f%%')
plt.show()

# %% [markdown]
# **Bar Plot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
plt.figure(figsize=(10,4))
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=6)
df.plot.bar(x='Year',y='Total expenditure')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **PAIRPLOT**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
##df1 = df[df['Year']>2015]
x=df['Polio']
y=df['infant deaths']
plt.scatter(x, y,cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# **CORRELATION HEATMAP**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
sns.heatmap(df.corr(),annot=True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# **HISTPLOT**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
plt.figure(figsize=(9,6))
sns.histplot(df['Year'],palette='Spectral',kde=True,binwidth=2)
plt.grid(axis='y',color='green',linestyle='--',linewidth=0.5)
plt.show()

# %% [markdown]
# **Selecting 3 Columns Randomly**

# %%
import numpy as np
import pandas as pd
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
df4=df[['Year','Status','Adult Mortality']]
df4
# Out:
#       Year      Status  Adult Mortality
# 0     2015  Developing            263.0
# 1     2014  Developing            271.0
# 2     2013  Developing            268.0
# 3     2012  Developing            272.0
# 4     2011  Developing            275.0
# ...    ...         ...              ...
# 2933  2004  Developing            723.0
# 2934  2003  Developing            715.0
# 2935  2002  Developing             73.0
# 2936  2001  Developing            686.0
# 2937  2000  Developing            665.0
#
# [2938 rows x 3 columns]

# %% [markdown]
# **Line Plot**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('/content/Life Expectancy Data.xlsx')
df4=df[['Year','Status','Adult Mortality']]
sns.lineplot(x='Year',y='Adult Mortality',data=df4)
plt.show()
